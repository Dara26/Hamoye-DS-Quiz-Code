# %%
#Question 1
#f1 score = 2*(precision * recall)/(precision + recall)
#Calculate Precision(TP/(TP + FP))
precision_spam = 355/(355+1480)
#Calculate Recall(TP/(TP + FN))
recall_spam = 355/(355+45)
#Calculate f1 score
round(2*(precision_spam * recall_spam)/(precision_spam + recall_spam),4)
# Out:
# 0.3177

# %%
#import csv file
import numpy as np
import pandas as pd
df = pd.read_csv('Data_for_UCI_named.csv',error_bad_lines=False)
df.head(20)
# Out:
#         tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0   2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1   9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2   8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3   0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4   3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# 5   6.999209  9.109247  3.784066  4.267788  4.429669 -1.857139 -0.670397
# 6   6.710166  3.765204  6.929314  8.818562  2.397419 -0.614590 -1.208826
# 7   6.953512  1.379125  5.719400  7.870307  3.224495 -0.748998 -1.186517
# 8   4.689852  4.007747  1.478573  3.733787  4.041300 -1.410344 -1.238204
# 9   9.841496  1.413822  9.769856  7.641616  4.727595 -1.991363 -0.857637
# 10  5.930110  6.730873  6.245138  0.533288  2.327092 -0.702501 -1.116920
# 11  5.381299  8.014521  8.095174  6.769248  5.507551 -1.972714 -1.849333
# ...

# %%
#drop stab column to leave stabf as sole dependent variable
df.drop('stab',inplace=True,axis=1)
df.head()
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1  9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2  8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3  0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4  3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
#
#          p4        g1        g2        g3        g4     stabf
# 0 -1.723086  0.650456  0.859578  0.887445  0.958034  unstable
# 1 -1.255012  0.413441  0.862414  0.562139  0.781760    stable
# 2 -0.920492  0.163041  0.766689  0.839444  0.109853  unstable
# 3 -0.997374  0.446209  0.976744  0.929381  0.362718  unstable
# 4 -0.554305  0.797110  0.455450  0.656947  0.820923  unstable

# %%
#Split data into train and test sets
X = df.drop('stabf',axis=1)
y = df.stabf
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
#Standardize training and testing datasets
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x_train)
x_train_normalized = scaler.transform(x_train)
x_test_normalized = scaler.transform(x_test)
x_train_normalized_df = pd.DataFrame(x_train_normalized, columns = x_train.columns)
x_test_normalized_df = pd.DataFrame(x_test_normalized, columns = x_test.columns)

# %%
#train a random forest classifier
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(random_state=1)
rfc.fit(x_train_normalized_df,y_train)
rfc_pred=rfc.predict(x_test_normalized_df)

# %%
#Question 14
#Calculate accuracy score using random forest classifier
from sklearn.metrics import accuracy_score
accuracy_rfc = accuracy_score(y_test, rfc_pred)
accuracy_rfc.round(4)
# Out:
# 0.929

# %%
#train an extreme boosting model
from xgboost import XGBClassifier
XGB=XGBClassifier(random_state=1)
XGB.fit(x_train_normalized_df,y_train)
XGB_pred=XGB.predict(x_test_normalized_df)

# %%
#Question 15
#Calculate accuracy score using xgboost
accuracy_xgb = accuracy_score(y_test, XGB_pred)
accuracy_xgb.round(4)
# Out:
# 0.9195

# %%
#train a light gradient boosting model
from lightgbm import LGBMClassifier
LGBM=LGBMClassifier(random_state=1)
LGBM.fit(x_train_normalized_df,y_train)
LGBM_pred=LGBM.predict(x_test_normalized_df)

# %%
#Question 16
#Calculate accuracy score using lgbm
accuracy_lgbm = accuracy_score(y_test, LGBM_pred)
accuracy_lgbm.round(4)
# Out:
# 0.9375

# %%
#train an extra trees classifier
from sklearn.ensemble import ExtraTreesClassifier
ETC=ExtraTreesClassifier(random_state=1)
ETC.fit(x_train_normalized_df,y_train)
ETC_pred=ETC.predict(x_test_normalized_df)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,ETC_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#       stable     0.9410    0.8511    0.8938       712
#     unstable     0.9218    0.9705    0.9455      1288
#
#     accuracy                         0.9280      2000
#    macro avg     0.9314    0.9108    0.9197      2000
# weighted avg     0.9287    0.9280    0.9271      2000

# %%
n_estimators = [50, 100, 300, 500, 1000]

min_samples_split = [2, 3, 5, 7, 9]

min_samples_leaf = [1, 2, 4, 6, 8]

max_features = ['auto', 'sqrt', 'log2', None]

# %%
hyperparameter_grid = {'n_estimators': n_estimators,

                       'min_samples_leaf': min_samples_leaf,

                       'min_samples_split': min_samples_split,

                       'max_features': max_features}

# %%
#Run a randomized cross validation search using the hyper parameter grid
from sklearn.model_selection import RandomizedSearchCV
Random_inputs=RandomizedSearchCV(ExtraTreesClassifier(random_state=1),
                                hyperparameter_grid, random_state = 1,cv=5,verbose=1,
                               scoring = 'accuracy', n_jobs=-1, n_iter = 10).fit(x_train_normalized_df,y_train).best_estimator_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:  1.2min finished

# %%
ETC_pred2=Random_inputs.predict(x_test_normalized_df)
print(classification_report(y_test,ETC_pred2, digits = 4))
# Out:
#               precision    recall  f1-score   support
#
#       stable     0.9211    0.8694    0.8945       712
#     unstable     0.9300    0.9589    0.9442      1288
#
#     accuracy                         0.9270      2000
#    macro avg     0.9256    0.9141    0.9193      2000
# weighted avg     0.9268    0.9270    0.9265      2000

# %%
#Question 17
#Best hyperparameters from the randomized search CV
Random_inputs=RandomizedSearchCV(ExtraTreesClassifier(),
                                hyperparameter_grid, random_state = 1,cv=5,verbose=1,
                               scoring = 'accuracy', n_jobs=-1, n_iter = 10).fit(x_train_normalized_df,y_train).best_params_
Random_inputs
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   56.8s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:  1.1min finished
# {'n_estimators': 50,
#  'min_samples_split': 5,
#  'min_samples_leaf': 8,
#  'max_features': None}

# %%
#Question 20
#Features with the most and least importance
importance = ETC.feature_importances_
features = pd.Series(importance, index = x_train.columns).sort_values(ascending=False)
features_df = pd.DataFrame(features).reset_index()
features_df.columns = ['Features', 'Importance']
features_df
# Out:
#    Features  Importance
# 0      tau2    0.118445
# 1      tau1    0.117397
# 2      tau4    0.115466
# 3      tau3    0.113169
# 4        g3    0.096883
# 5        g4    0.094019
# 6        g2    0.093676
# 7        g1    0.089783
# 8        p3    0.040706
# 9        p4    0.040579
# 10       p2    0.040371
# 11       p1    0.039507

# %%
#visualization of feature importance from highest to lowest
import matplotlib.pyplot as plt
import seaborn as sns
indices = np.argsort(importance)[::-1]
plt.figure(figsize=(10,7))
plt.xticks(rotation=360)
plt.title("Feature Importance from highest to lowest")
sns.barplot(x = x_train.columns[indices], y = importance[indices])
